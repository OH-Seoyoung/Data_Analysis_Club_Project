# %% [markdown]
# # Single-Layer Perceptron with MNIST

# %% [markdown]
# ## 1. Import Packages

# %%
import input_data
import numpy as np
import matplotlib.pylab as plt
from keras import models
from keras import layers
from keras.utils import to_categorical
from tensorflow import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 2. Explore MNIST Data

# %%
mnist_images = input_data.read_data_sets("./mnist_data", one_hot=False)  # MNIST 데이터를 불러와서 저장
# Out:
# Extracting ./mnist_data\train-images-idx3-ubyte.gz
# Extracting ./mnist_data\train-labels-idx1-ubyte.gz
# Extracting ./mnist_data\t10k-images-idx3-ubyte.gz
# Extracting ./mnist_data\t10k-labels-idx1-ubyte.gz

# %%
#  Example of a picture
pic,real_values = mnist_images.train.next_batch(25)   

index = 11   # 0~24 integer
image = pic[index,:]
image = np.reshape(image,[28,28])
plt.imshow(image)
plt.xlabel(real_values[index], fontsize=30)
plt.show()

# %%
# Explore MNIST data

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image = np.reshape(pic[i,:] , [28,28])
    plt.imshow(image)
    plt.xlabel(real_values[i])
plt.show()

# %% [markdown]
# ## 3. Make Dataset

# %%
# Download Data : http://yann.lecun.com/exdb/mnist/
# Data input script : https://github.com/tensorflow/tensorflow/tree/master/tensorflow/examples/tutorials/mnist

mnist = input_data.read_data_sets("./samples/MNIST_data/", one_hot = False)
# Out:
# Extracting ./samples/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./samples/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./samples/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./samples/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
print("the number of train examples :" , mnist.train.num_examples)
print("the number of test examples :" , mnist.test.num_examples)
# Out:
# the number of train examples : 55000
# the number of test examples : 10000

# %%
x_train_orig = mnist.train.images.reshape((55000, 28 * 28))
x_test_orig = mnist.test.images.reshape((10000, 28 * 28))

# %%
# Normalization
x_train = x_train_orig.astype('float32') / 255
x_test = x_test_orig.astype('float32') / 255

y_train = mnist.train.labels
y_test = mnist.test.labels

# %% [markdown]
# ## 4. Single-Layer Perceptron with Softmax

# %%
model = models.Sequential()
model.add(layers.Dense(10, activation='softmax', input_shape=(28 * 28,)))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=100, batch_size=128)
# Out:
# Epoch 1/100
# 55000/55000 [==============================] - ETA: 0s - loss: 0.6895 - accuracy: 0.85 - 1s 15us/step - loss: 0.6896 - accuracy: 0.8540
# Epoch 2/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.6817 - accuracy: 0.8548
# Epoch 3/100
# 55000/55000 [==============================] - 1s 17us/step - loss: 0.6740 - accuracy: 0.8560
# Epoch 4/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.6666 - accuracy: 0.8567
# Epoch 5/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.6594 - accuracy: 0.8581
# Epoch 6/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.6524 - accuracy: 0.8585
# Epoch 7/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.6457 - accuracy: 0.8599
# Epoch 8/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.6391 - accuracy: 0.8605
# Epoch 9/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.6328 - accuracy: 0.8616
# Epoch 10/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.6267 - accuracy: 0.8621
# Epoch 11/100
# 55000/55000 [==============================] - 1s 17us/step - loss: 0.6207 - accuracy: 0.8629
# Epoch 12/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.6149 - accuracy: 0.8636
# Epoch 13/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.6093 - accuracy: 0.8640
# Epoch 14/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.6039 - accuracy: 0.8648
# Epoch 15/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5986 - accuracy: 0.8656
# Epoch 16/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.5935 - accuracy: 0.8661
# Epoch 17/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5885 - accuracy: 0.8665
# Epoch 18/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.5837 - accuracy: 0.8677
# Epoch 19/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5790 - accuracy: 0.8679
# Epoch 20/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5744 - accuracy: 0.8686
# Epoch 21/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5699 - accuracy: 0.8691
# Epoch 22/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5656 - accuracy: 0.8699
# Epoch 23/100
# 55000/55000 [==============================] - 1s 19us/step - loss: 0.5614 - accuracy: 0.8703
# Epoch 24/100
# 55000/55000 [==============================] - 1s 19us/step - loss: 0.5573 - accuracy: 0.8711
# Epoch 25/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.5533 - accuracy: 0.8713
# Epoch 26/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.5494 - accuracy: 0.8721
# Epoch 27/100
# 55000/55000 [==============================] - 1s 17us/step - loss: 0.5456 - accuracy: 0.8726
# Epoch 28/100
# 55000/55000 [==============================] - 1s 13us/step - loss: 0.5419 - accuracy: 0.8730
# Epoch 29/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.5383 - accuracy: 0.8733
# Epoch 30/100
# 55000/55000 [==============================] - 1s 17us/step - loss: 0.5348 - accuracy: 0.8740
# Epoch 31/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5314 - accuracy: 0.8745
# Epoch 32/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.5280 - accuracy: 0.8748
# Epoch 33/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.5248 - accuracy: 0.8755
# Epoch 34/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5216 - accuracy: 0.8757
# Epoch 35/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.5185 - accuracy: 0.8760
# Epoch 36/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.5155 - accuracy: 0.8766
# Epoch 37/100
# 55000/55000 [==============================] - 1s 21us/step - loss: 0.5125 - accuracy: 0.8769
# Epoch 38/100
# 55000/55000 [==============================] - 1s 17us/step - loss: 0.5096 - accuracy: 0.8775
# Epoch 39/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.5068 - accuracy: 0.8780
# Epoch 40/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.5040 - accuracy: 0.8782
# Epoch 41/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.5013 - accuracy: 0.8786
# Epoch 42/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4987 - accuracy: 0.8787
# Epoch 43/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4961 - accuracy: 0.8795
# Epoch 44/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4936 - accuracy: 0.8798
# Epoch 45/100
# 55000/55000 [==============================] - 1s 22us/step - loss: 0.4911 - accuracy: 0.8797
# Epoch 46/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4887 - accuracy: 0.8804
# Epoch 47/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4863 - accuracy: 0.8806
# Epoch 48/100
# 55000/55000 [==============================] - 1s 17us/step - loss: 0.4840 - accuracy: 0.8810
# Epoch 49/100
# 55000/55000 [==============================] - 1s 17us/step - loss: 0.4817 - accuracy: 0.8812
# Epoch 50/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.4795 - accuracy: 0.8818
# Epoch 51/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.4773 - accuracy: 0.8823
# Epoch 52/100
# 55000/55000 [==============================] - 1s 13us/step - loss: 0.4752 - accuracy: 0.8826
# Epoch 53/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4731 - accuracy: 0.8830
# Epoch 54/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4710 - accuracy: 0.8831
# Epoch 55/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4690 - accuracy: 0.8836
# Epoch 56/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4670 - accuracy: 0.8838
# Epoch 57/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4651 - accuracy: 0.8842
# Epoch 58/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4632 - accuracy: 0.8845
# Epoch 59/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4613 - accuracy: 0.8848
# Epoch 60/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4595 - accuracy: 0.8849
# Epoch 61/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4577 - accuracy: 0.8852
# Epoch 62/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4560 - accuracy: 0.8856
# Epoch 63/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4542 - accuracy: 0.8857
# Epoch 64/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.4525 - accuracy: 0.8861
# Epoch 65/100
# 55000/55000 [==============================] - 1s 20us/step - loss: 0.4509 - accuracy: 0.8861
# Epoch 66/100
# 55000/55000 [==============================] - 1s 17us/step - loss: 0.4492 - accuracy: 0.8863
# Epoch 67/100
# 55000/55000 [==============================] - 1s 22us/step - loss: 0.4476 - accuracy: 0.8867
# Epoch 68/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.4460 - accuracy: 0.8868
# Epoch 69/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4445 - accuracy: 0.8871
# Epoch 70/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4429 - accuracy: 0.8871
# Epoch 71/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4414 - accuracy: 0.8877
# Epoch 72/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4400 - accuracy: 0.8877
# Epoch 73/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4385 - accuracy: 0.8878
# Epoch 74/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4371 - accuracy: 0.8880
# Epoch 75/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4357 - accuracy: 0.8885
# Epoch 76/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4343 - accuracy: 0.8885
# Epoch 77/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4330 - accuracy: 0.8889
# Epoch 78/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4316 - accuracy: 0.8891
# Epoch 79/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4303 - accuracy: 0.8893
# Epoch 80/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4290 - accuracy: 0.8894
# Epoch 81/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4277 - accuracy: 0.8898
# Epoch 82/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4265 - accuracy: 0.8898
# Epoch 83/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4253 - accuracy: 0.8903
# Epoch 84/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4240 - accuracy: 0.8905
# Epoch 85/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4229 - accuracy: 0.8905
# Epoch 86/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4217 - accuracy: 0.8906
# Epoch 87/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4205 - accuracy: 0.8910
# Epoch 88/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4194 - accuracy: 0.8910
# Epoch 89/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4182 - accuracy: 0.8914
# Epoch 90/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4171 - accuracy: 0.8915
# Epoch 91/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4160 - accuracy: 0.8917
# Epoch 92/100
# 55000/55000 [==============================] - 1s 18us/step - loss: 0.4150 - accuracy: 0.8920
# Epoch 93/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4139 - accuracy: 0.8921
# Epoch 94/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4128 - accuracy: 0.8921 0s - l
# Epoch 95/100
# 55000/55000 [==============================] - 1s 14us/step - loss: 0.4118 - accuracy: 0.8922
# Epoch 96/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4108 - accuracy: 0.8924
# Epoch 97/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4098 - accuracy: 0.8927
# Epoch 98/100
# 55000/55000 [==============================] - 1s 16us/step - loss: 0.4088 - accuracy: 0.8927
# Epoch 99/100
# 55000/55000 [==============================] - 1s 19us/step - loss: 0.4078 - accuracy: 0.8930
# Epoch 100/100
# 55000/55000 [==============================] - 1s 15us/step - loss: 0.4069 - accuracy: 0.8931

# %%
train_loss, train_acc = model.evaluate(x_test, y_test, verbose=2)
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)

print('Train Accuracy:', train_acc)
print('Test Accuracy:', test_acc)
# Out:
# Train Accuracy: 0.9020000100135803
# Test Accuracy: 0.9020000100135803

# %%
predictions = model.predict(x_test)  #confidence

# %%
predictions[0] # confidence of first image in test set
# Out:
# array([2.76045495e-04, 1.58797793e-05, 2.93608551e-04, 2.14567850e-03,
#        3.99867218e-04, 5.87953138e-04, 1.23788295e-05, 9.88341749e-01,
#        1.93344807e-04, 7.73343211e-03], dtype=float32)

# %%
print(np.argmax(predictions[0]))  # highest confidence
# This model is convinced that this image is "7"

image = x_test[0,:]
image = np.reshape(image,[28,28])
plt.imshow(image)
# Out:
# 7
