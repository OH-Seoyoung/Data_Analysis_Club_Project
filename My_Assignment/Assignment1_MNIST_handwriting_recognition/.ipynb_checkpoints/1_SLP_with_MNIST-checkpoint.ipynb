# %% [markdown]
# # Single-Layer Perceptron with MNIST

# %% [markdown]
# ## 1. Import Packages

# %%
import input_data
import numpy as np
import matplotlib.pylab as plt
from keras import models
from keras import layers
from keras.utils import to_categorical
from tensorflow import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 2. Explore MNIST Data

# %%
mnist_images = input_data.read_data_sets("./mnist_data", one_hot=False)  # MNIST 데이터를 불러와서 저장
# Out:
# Extracting ./mnist_data\train-images-idx3-ubyte.gz
# Extracting ./mnist_data\train-labels-idx1-ubyte.gz
# Extracting ./mnist_data\t10k-images-idx3-ubyte.gz
# Extracting ./mnist_data\t10k-labels-idx1-ubyte.gz

# %%
#  Example of a picture
pic,real_values = mnist_images.train.next_batch(25)   

index = 11   # 0~24 integer
image = pic[index,:]
image = np.reshape(image,[28,28])
plt.imshow(image)
plt.xlabel(real_values[index], fontsize=30)
plt.show()

# %%
# Explore MNIST data

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    image = np.reshape(pic[i,:] , [28,28])
    plt.imshow(image)
    plt.xlabel(real_values[i])
plt.show()

# %% [markdown]
# ## 3. Make Dataset

# %%
# Download Data : http://yann.lecun.com/exdb/mnist/
# Data input script : https://github.com/tensorflow/tensorflow/tree/master/tensorflow/examples/tutorials/mnist

mnist = input_data.read_data_sets("./samples/MNIST_data/", one_hot = False)
# Out:
# Extracting ./samples/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./samples/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./samples/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./samples/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
print("the number of train examples :" , mnist.train.num_examples)
print("the number of test examples :" , mnist.test.num_examples)
# Out:
# the number of train examples : 55000
# the number of test examples : 10000

# %%
x_train_orig = mnist.train.images.reshape((55000, 28 * 28))
x_test_orig = mnist.test.images.reshape((10000, 28 * 28))

# %%
# Normalization
x_train = x_train_orig.astype('float32') / 255
x_test = x_test_orig.astype('float32') / 255

y_train = mnist.train.labels
y_test = mnist.test.labels

# %% [markdown]
# ## 4. Single-Layer Perceptron with Softmax

# %%
model = models.Sequential()
model.add(layers.Dense(10, activation='softmax', input_shape=(28 * 28,)))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=200, batch_size=128, verbose=2)
# Out:
# Epoch 1/200
#  - 1s - loss: 2.2671 - accuracy: 0.4513
# Epoch 2/200
#  - 0s - loss: 2.1988 - accuracy: 0.5723
# Epoch 3/200
#  - 0s - loss: 2.1330 - accuracy: 0.6499
# Epoch 4/200
#  - 0s - loss: 2.0695 - accuracy: 0.6759
# Epoch 5/200
#  - 0s - loss: 2.0081 - accuracy: 0.7065
# Epoch 6/200
#  - 0s - loss: 1.9489 - accuracy: 0.7151
# Epoch 7/200
#  - 0s - loss: 1.8917 - accuracy: 0.7307
# Epoch 8/200
#  - 0s - loss: 1.8366 - accuracy: 0.7376
# Epoch 9/200
#  - 0s - loss: 1.7835 - accuracy: 0.7499
# Epoch 10/200
#  - 0s - loss: 1.7323 - accuracy: 0.7513
# Epoch 11/200
#  - 0s - loss: 1.6829 - accuracy: 0.7614
# Epoch 12/200
#  - 0s - loss: 1.6354 - accuracy: 0.7651
# Epoch 13/200
#  - 0s - loss: 1.5897 - accuracy: 0.7702
# Epoch 14/200
#  - 0s - loss: 1.5458 - accuracy: 0.7752
# Epoch 15/200
#  - 0s - loss: 1.5035 - accuracy: 0.7780
# Epoch 16/200
#  - 0s - loss: 1.4629 - accuracy: 0.7832
# Epoch 17/200
#  - 0s - loss: 1.4240 - accuracy: 0.7860
# Epoch 18/200
#  - 0s - loss: 1.3867 - accuracy: 0.7889
# Epoch 19/200
#  - 0s - loss: 1.3509 - accuracy: 0.7924
# Epoch 20/200
#  - 0s - loss: 1.3166 - accuracy: 0.7957
# Epoch 21/200
#  - 0s - loss: 1.2837 - accuracy: 0.7969
# Epoch 22/200
#  - 0s - loss: 1.2522 - accuracy: 0.8010
# Epoch 23/200
#  - 0s - loss: 1.2220 - accuracy: 0.8037
# Epoch 24/200
#  - 0s - loss: 1.1931 - accuracy: 0.8061
# Epoch 25/200
#  - 1s - loss: 1.1654 - accuracy: 0.8075
# Epoch 26/200
#  - 1s - loss: 1.1388 - accuracy: 0.8096
# Epoch 27/200
#  - 0s - loss: 1.1134 - accuracy: 0.8122
# Epoch 28/200
#  - 0s - loss: 1.0890 - accuracy: 0.8139
# Epoch 29/200
#  - 0s - loss: 1.0657 - accuracy: 0.8164
# Epoch 30/200
#  - 0s - loss: 1.0433 - accuracy: 0.8183
# Epoch 31/200
#  - 1s - loss: 1.0218 - accuracy: 0.8197
# Epoch 32/200
#  - 0s - loss: 1.0013 - accuracy: 0.8216
# Epoch 33/200
#  - 1s - loss: 0.9815 - accuracy: 0.8236
# Epoch 34/200
#  - 0s - loss: 0.9626 - accuracy: 0.8249
# Epoch 35/200
#  - 1s - loss: 0.9445 - accuracy: 0.8265
# Epoch 36/200
#  - 0s - loss: 0.9270 - accuracy: 0.8282
# Epoch 37/200
#  - 0s - loss: 0.9103 - accuracy: 0.8294
# Epoch 38/200
#  - 0s - loss: 0.8942 - accuracy: 0.8310
# Epoch 39/200
#  - 0s - loss: 0.8788 - accuracy: 0.8330
# Epoch 40/200
#  - 0s - loss: 0.8640 - accuracy: 0.8345
# Epoch 41/200
#  - 0s - loss: 0.8497 - accuracy: 0.8360
# Epoch 42/200
#  - 1s - loss: 0.8360 - accuracy: 0.8374
# Epoch 43/200
#  - 0s - loss: 0.8228 - accuracy: 0.8395
# Epoch 44/200
#  - 0s - loss: 0.8101 - accuracy: 0.8408
# Epoch 45/200
#  - 0s - loss: 0.7979 - accuracy: 0.8423
# Epoch 46/200
#  - 0s - loss: 0.7862 - accuracy: 0.8433
# Epoch 47/200
#  - 0s - loss: 0.7748 - accuracy: 0.8438
# Epoch 48/200
#  - 0s - loss: 0.7639 - accuracy: 0.8460
# Epoch 49/200
#  - 0s - loss: 0.7534 - accuracy: 0.8471
# Epoch 50/200
#  - 1s - loss: 0.7433 - accuracy: 0.8480
# Epoch 51/200
#  - 0s - loss: 0.7336 - accuracy: 0.8485
# Epoch 52/200
#  - 0s - loss: 0.7241 - accuracy: 0.8499
# Epoch 53/200
#  - 0s - loss: 0.7150 - accuracy: 0.8508
# Epoch 54/200
#  - 0s - loss: 0.7062 - accuracy: 0.8520
# Epoch 55/200
#  - 0s - loss: 0.6977 - accuracy: 0.8527
# Epoch 56/200
#  - 0s - loss: 0.6895 - accuracy: 0.8540
# Epoch 57/200
#  - 0s - loss: 0.6816 - accuracy: 0.8549
# Epoch 58/200
#  - 0s - loss: 0.6739 - accuracy: 0.8557
# Epoch 59/200
#  - 0s - loss: 0.6664 - accuracy: 0.8574
# Epoch 60/200
#  - 0s - loss: 0.6592 - accuracy: 0.8579
# Epoch 61/200
#  - 0s - loss: 0.6523 - accuracy: 0.8588
# Epoch 62/200
#  - 0s - loss: 0.6455 - accuracy: 0.8600
# Epoch 63/200
#  - 0s - loss: 0.6390 - accuracy: 0.8606
# Epoch 64/200
#  - 0s - loss: 0.6327 - accuracy: 0.8614
# Epoch 65/200
#  - 0s - loss: 0.6266 - accuracy: 0.8621
# Epoch 66/200
#  - 0s - loss: 0.6206 - accuracy: 0.8627
# Epoch 67/200
#  - 0s - loss: 0.6149 - accuracy: 0.8639
# Epoch 68/200
#  - 0s - loss: 0.6093 - accuracy: 0.8639
# Epoch 69/200
#  - 0s - loss: 0.6039 - accuracy: 0.8648
# Epoch 70/200
#  - 0s - loss: 0.5986 - accuracy: 0.8656
# Epoch 71/200
#  - 0s - loss: 0.5934 - accuracy: 0.8660
# Epoch 72/200
#  - 0s - loss: 0.5885 - accuracy: 0.8668
# Epoch 73/200
#  - 0s - loss: 0.5836 - accuracy: 0.8674
# Epoch 74/200
#  - 0s - loss: 0.5789 - accuracy: 0.8678
# Epoch 75/200
#  - 0s - loss: 0.5744 - accuracy: 0.8688
# Epoch 76/200
#  - 0s - loss: 0.5699 - accuracy: 0.8691
# Epoch 77/200
#  - 1s - loss: 0.5656 - accuracy: 0.8696
# Epoch 78/200
#  - 1s - loss: 0.5614 - accuracy: 0.8702
# Epoch 79/200
#  - 1s - loss: 0.5572 - accuracy: 0.8708
# Epoch 80/200
#  - 1s - loss: 0.5532 - accuracy: 0.8717
# Epoch 81/200
#  - 1s - loss: 0.5494 - accuracy: 0.8720
# Epoch 82/200
#  - 1s - loss: 0.5456 - accuracy: 0.8726
# Epoch 83/200
#  - 0s - loss: 0.5419 - accuracy: 0.8727
# Epoch 84/200
#  - 0s - loss: 0.5383 - accuracy: 0.8737
# Epoch 85/200
#  - 0s - loss: 0.5348 - accuracy: 0.8739
# Epoch 86/200
#  - 0s - loss: 0.5313 - accuracy: 0.8748
# Epoch 87/200
#  - 0s - loss: 0.5280 - accuracy: 0.8751
# Epoch 88/200
#  - 0s - loss: 0.5248 - accuracy: 0.8755
# Epoch 89/200
#  - 0s - loss: 0.5216 - accuracy: 0.8762
# Epoch 90/200
#  - 0s - loss: 0.5185 - accuracy: 0.8763
# Epoch 91/200
#  - 0s - loss: 0.5155 - accuracy: 0.8767
# Epoch 92/200
#  - 0s - loss: 0.5125 - accuracy: 0.8771
# Epoch 93/200
#  - 0s - loss: 0.5096 - accuracy: 0.8776
# Epoch 94/200
#  - 0s - loss: 0.5068 - accuracy: 0.8774
# Epoch 95/200
#  - 0s - loss: 0.5040 - accuracy: 0.8780
# Epoch 96/200
#  - 0s - loss: 0.5013 - accuracy: 0.8784
# Epoch 97/200
#  - 0s - loss: 0.4987 - accuracy: 0.8789
# Epoch 98/200
#  - 0s - loss: 0.4961 - accuracy: 0.8791
# Epoch 99/200
#  - 0s - loss: 0.4936 - accuracy: 0.8798
# Epoch 100/200
#  - 0s - loss: 0.4911 - accuracy: 0.8801
# Epoch 101/200
#  - 0s - loss: 0.4887 - accuracy: 0.8807
# Epoch 102/200
#  - 1s - loss: 0.4863 - accuracy: 0.8805
# Epoch 103/200
#  - 1s - loss: 0.4840 - accuracy: 0.8811
# Epoch 104/200
#  - 1s - loss: 0.4817 - accuracy: 0.8814
# Epoch 105/200
#  - 1s - loss: 0.4795 - accuracy: 0.8818
# Epoch 106/200
#  - 1s - loss: 0.4773 - accuracy: 0.8823
# Epoch 107/200
#  - 1s - loss: 0.4752 - accuracy: 0.8825
# Epoch 108/200
#  - 0s - loss: 0.4731 - accuracy: 0.8827
# Epoch 109/200
#  - 1s - loss: 0.4710 - accuracy: 0.8830
# Epoch 110/200
#  - 1s - loss: 0.4690 - accuracy: 0.8834
# Epoch 111/200
#  - 0s - loss: 0.4670 - accuracy: 0.8837
# Epoch 112/200
#  - 0s - loss: 0.4651 - accuracy: 0.8842
# Epoch 113/200
#  - 0s - loss: 0.4632 - accuracy: 0.8845
# Epoch 114/200
#  - 1s - loss: 0.4613 - accuracy: 0.8847
# Epoch 115/200
#  - 0s - loss: 0.4595 - accuracy: 0.8849
# Epoch 116/200
#  - 0s - loss: 0.4577 - accuracy: 0.8854
# Epoch 117/200
#  - 0s - loss: 0.4559 - accuracy: 0.8854
# Epoch 118/200
#  - 0s - loss: 0.4542 - accuracy: 0.8858
# Epoch 119/200
#  - 0s - loss: 0.4525 - accuracy: 0.8859
# Epoch 120/200
#  - 0s - loss: 0.4509 - accuracy: 0.8863
# Epoch 121/200
#  - 0s - loss: 0.4492 - accuracy: 0.8865
# Epoch 122/200
#  - 0s - loss: 0.4476 - accuracy: 0.8867
# Epoch 123/200
#  - 0s - loss: 0.4460 - accuracy: 0.8871
# Epoch 124/200
#  - 0s - loss: 0.4445 - accuracy: 0.8870
# Epoch 125/200
#  - 0s - loss: 0.4430 - accuracy: 0.8872
# Epoch 126/200
#  - 0s - loss: 0.4415 - accuracy: 0.8875
# Epoch 127/200
#  - 0s - loss: 0.4400 - accuracy: 0.8877
# Epoch 128/200
#  - 0s - loss: 0.4386 - accuracy: 0.8879
# Epoch 129/200
#  - 0s - loss: 0.4371 - accuracy: 0.8883
# Epoch 130/200
#  - 0s - loss: 0.4357 - accuracy: 0.8886
# Epoch 131/200
#  - 0s - loss: 0.4343 - accuracy: 0.8890
# Epoch 132/200
#  - 0s - loss: 0.4330 - accuracy: 0.8886
# Epoch 133/200
#  - 0s - loss: 0.4317 - accuracy: 0.8891
# Epoch 134/200
#  - 0s - loss: 0.4303 - accuracy: 0.8894
# Epoch 135/200
#  - 0s - loss: 0.4291 - accuracy: 0.8896
# Epoch 136/200
#  - 0s - loss: 0.4278 - accuracy: 0.8897
# Epoch 137/200
#  - 0s - loss: 0.4265 - accuracy: 0.8897
# Epoch 138/200
#  - 0s - loss: 0.4253 - accuracy: 0.8900
# Epoch 139/200
#  - 0s - loss: 0.4241 - accuracy: 0.8902
# Epoch 140/200
#  - 0s - loss: 0.4229 - accuracy: 0.8905
# Epoch 141/200
#  - 0s - loss: 0.4217 - accuracy: 0.8907
# Epoch 142/200
#  - 0s - loss: 0.4205 - accuracy: 0.8910
# Epoch 143/200
#  - 0s - loss: 0.4194 - accuracy: 0.8909
# Epoch 144/200
#  - 0s - loss: 0.4183 - accuracy: 0.8913
# Epoch 145/200
#  - 0s - loss: 0.4171 - accuracy: 0.8913
# Epoch 146/200
#  - 0s - loss: 0.4160 - accuracy: 0.8918
# Epoch 147/200
#  - 0s - loss: 0.4150 - accuracy: 0.8919
# Epoch 148/200
#  - 0s - loss: 0.4139 - accuracy: 0.8919
# Epoch 149/200
#  - 0s - loss: 0.4129 - accuracy: 0.8922
# Epoch 150/200
#  - 0s - loss: 0.4118 - accuracy: 0.8925
# Epoch 151/200
#  - 0s - loss: 0.4108 - accuracy: 0.8924
# Epoch 152/200
#  - 0s - loss: 0.4098 - accuracy: 0.8928
# Epoch 153/200
#  - 0s - loss: 0.4088 - accuracy: 0.8927
# Epoch 154/200
#  - 0s - loss: 0.4078 - accuracy: 0.8928
# Epoch 155/200
#  - 0s - loss: 0.4069 - accuracy: 0.8929
# Epoch 156/200
#  - 0s - loss: 0.4059 - accuracy: 0.8933
# Epoch 157/200
#  - 0s - loss: 0.4050 - accuracy: 0.8934
# Epoch 158/200
#  - 0s - loss: 0.4041 - accuracy: 0.8936
# Epoch 159/200
#  - 0s - loss: 0.4031 - accuracy: 0.8938
# Epoch 160/200
#  - 0s - loss: 0.4023 - accuracy: 0.8935
# Epoch 161/200
#  - 0s - loss: 0.4014 - accuracy: 0.8938
# Epoch 162/200
#  - 0s - loss: 0.4005 - accuracy: 0.8940
# Epoch 163/200
#  - 0s - loss: 0.3996 - accuracy: 0.8940
# Epoch 164/200
#  - 0s - loss: 0.3988 - accuracy: 0.8943
# Epoch 165/200
#  - 1s - loss: 0.3979 - accuracy: 0.8947
# Epoch 166/200
#  - 0s - loss: 0.3971 - accuracy: 0.8947
# Epoch 167/200
#  - 0s - loss: 0.3963 - accuracy: 0.8947
# Epoch 168/200
#  - 1s - loss: 0.3954 - accuracy: 0.8949
# Epoch 169/200
#  - 0s - loss: 0.3946 - accuracy: 0.8950
# Epoch 170/200
#  - 0s - loss: 0.3938 - accuracy: 0.8952
# Epoch 171/200
#  - 0s - loss: 0.3931 - accuracy: 0.8954
# Epoch 172/200
#  - 0s - loss: 0.3923 - accuracy: 0.8956
# Epoch 173/200
#  - 0s - loss: 0.3915 - accuracy: 0.8955
# Epoch 174/200
#  - 0s - loss: 0.3908 - accuracy: 0.8957
# Epoch 175/200
#  - 0s - loss: 0.3900 - accuracy: 0.8960
# Epoch 176/200
#  - 0s - loss: 0.3893 - accuracy: 0.8961
# Epoch 177/200
#  - 0s - loss: 0.3885 - accuracy: 0.8964
# Epoch 178/200
#  - 0s - loss: 0.3878 - accuracy: 0.8964
# Epoch 179/200
#  - 0s - loss: 0.3871 - accuracy: 0.8965
# Epoch 180/200
#  - 0s - loss: 0.3864 - accuracy: 0.8968
# Epoch 181/200
#  - 0s - loss: 0.3857 - accuracy: 0.8968
# Epoch 182/200
#  - 0s - loss: 0.3850 - accuracy: 0.8971
# Epoch 183/200
#  - 0s - loss: 0.3843 - accuracy: 0.8973
# Epoch 184/200
#  - 0s - loss: 0.3837 - accuracy: 0.8972
# Epoch 185/200
#  - 0s - loss: 0.3830 - accuracy: 0.8973
# Epoch 186/200
#  - 0s - loss: 0.3823 - accuracy: 0.8977
# Epoch 187/200
#  - 0s - loss: 0.3817 - accuracy: 0.8976
# Epoch 188/200
#  - 0s - loss: 0.3810 - accuracy: 0.8976
# Epoch 189/200
#  - 0s - loss: 0.3804 - accuracy: 0.8979
# Epoch 190/200
#  - 0s - loss: 0.3798 - accuracy: 0.8977
# Epoch 191/200
#  - 0s - loss: 0.3791 - accuracy: 0.8981
# Epoch 192/200
#  - 0s - loss: 0.3785 - accuracy: 0.8983
# Epoch 193/200
#  - 0s - loss: 0.3779 - accuracy: 0.8985
# Epoch 194/200
#  - 0s - loss: 0.3773 - accuracy: 0.8986
# Epoch 195/200
#  - 0s - loss: 0.3767 - accuracy: 0.8986
# Epoch 196/200
#  - 0s - loss: 0.3761 - accuracy: 0.8986
# Epoch 197/200
#  - 0s - loss: 0.3755 - accuracy: 0.8990
# Epoch 198/200
#  - 0s - loss: 0.3749 - accuracy: 0.8991
# Epoch 199/200
#  - 0s - loss: 0.3744 - accuracy: 0.8991
# Epoch 200/200
#  - 0s - loss: 0.3738 - accuracy: 0.8991

# %% [markdown]
# ## 5. Accuracy Analysis

# %%
train_loss, train_acc = model.evaluate(x_train, y_train, verbose=2)
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)

print('Train Accuracy:', train_acc)
print('Test Accuracy:', test_acc)
# Out:
# Train Accuracy: 0.8994181752204895
# Test Accuracy: 0.9071999788284302

# %% [markdown]
# ## 6. Check a prediction

# %%
predictions = model.predict(x_test)  #confidence

# %%
predictions[0] # confidence of first image in test set
# Out:
# array([1.6505763e-04, 4.4272206e-06, 1.7270874e-04, 1.7022940e-03,
#        1.6773239e-04, 3.3796515e-04, 3.8188405e-06, 9.9230814e-01,
#        1.0181268e-04, 5.0360621e-03], dtype=float32)

# %%
print(np.argmax(predictions[0]))  # highest confidence
# This model is convinced that this image is "7"

image = x_test[0,:]
image = np.reshape(image,[28,28])
plt.imshow(image)
# Out:
# 7

# %% [markdown]
# ## 7. Save model

# %%
# Save model
model_json = model.to_json()
with open("slp.json", "w") as json_file : 
    json_file.write(model_json)
    
# Save model weights
model.save_weights("slp_weight.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Load trained model
from keras.models import model_from_json 
json_file = open("slp.json", "r")
loaded_model_json = json_file.read() 
json_file.close()
loaded_model = model_from_json(loaded_model_json)
 
# model weight load 
loaded_model.load_weights("slp_weight.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# evaluate
loaded_model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
train_score = loaded_model.evaluate(x_train, y_train, verbose=0)
test_score = loaded_model.evaluate(x_test, y_test, verbose=0)
 
print('training accuracy : ' + str(train_score[1]))
print('test accuracy : ' + str(test_score[1]))
# Out:
# training accuracy : 0.8994181752204895
# test accuracy : 0.9071999788284302
